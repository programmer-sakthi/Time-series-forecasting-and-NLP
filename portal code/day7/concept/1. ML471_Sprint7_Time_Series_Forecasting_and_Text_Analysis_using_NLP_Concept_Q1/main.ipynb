# %%
import spacy
import pandas as pd
from spacy import displacy
import os
import webbrowser

# %%
# ================================
# LOAD NLP MODEL
# ================================
nlp = spacy.load("en_core_web_sm")

# ================================
# SAMPLE SENTENCES
# ================================
sentences = [
    "The dollar has hit its highest level against the euro after the Federal Reserve head said the US trade deficit is set to stabilize.",
    "Quarterly profits at US media giant TimeWarner jumped 76% to $1.13bn.",
    "The cat wearing sunglasses danced on the rooftop under the moonlight."
]

# ================================
# FUNCTION: DEPENDENCY TABLE
# ================================
def dependency_table(doc):
    data = []
    for token in doc:
        data.append([
            token.text,
            token.lemma_,
            token.pos_,
            token.dep_,
            token.head.text
        ])

    df = pd.DataFrame(data, columns=[
        "Token",
        "Lemma",
        "POS",
        "Dependency",
        "Head Word"
    ])

    return df

# %%
# ================================
# FUNCTION: VISUALIZE TREE IN BROWSER
# ================================
def visualize_tree(doc, filename="dependency_tree.html"):
    html = displacy.render(
        doc,
        style="dep",
        options={"distance": 110}
    )

    with open(filename, "w", encoding="utf-8") as f:
        f.write(html)

    webbrowser.open("file://" + os.path.realpath(filename))


# ================================
# PROCESS SAMPLE SENTENCES
# ================================
print("\n================ SAMPLE SENTENCES ================\n")

for i, sent in enumerate(sentences):
    print("\n" + "=" * 90)
    print("Sentence:\n", sent)

    doc = nlp(sent)

    df = dependency_table(doc)
    print("\nDependency Table:\n")
    print(df)

    print("\nDependency Tree opening in browser...\n")
    visualize_tree(doc, f"sample_tree_{i}.html")
# Out:
# ================ SAMPLE SENTENCES ================
#
#
# ==========================================================================================
# Sentence:
#  The dollar has hit its highest level against the euro after the Federal Reserve head said the US trade deficit is set to stabilize.
#
# Dependency Table:
#
#         Token      Lemma    POS Dependency  Head Word
# 0         The        the    DET        det     dollar
# 1      dollar     dollar   NOUN      nsubj        hit
# 2         has       have    AUX        aux        hit
# 3         hit        hit   VERB       ROOT        hit
# 4         its        its   PRON       poss      level
# 5     highest       high    ADJ       amod      level
# 6       level      level   NOUN       dobj        hit
# 7     against    against    ADP       prep      level
# 8         the        the    DET        det       euro
# 9        euro       euro   NOUN       pobj    against
# 10      after      after  SCONJ       mark       said
# 11        the        the    DET        det       head
# 12    Federal    Federal  PROPN   compound    Reserve
# 13    Reserve    Reserve  PROPN   compound       head
# 14       head       head   NOUN      nsubj       said
# 15       said        say   VERB      advcl        hit
# 16        the        the    DET        det    deficit
# 17         US         US  PROPN   compound    deficit
# 18      trade      trade   NOUN   compound    deficit
# 19    deficit    deficit   NOUN  nsubjpass        set
# 20         is         be    AUX    auxpass        set
# 21        set        set   VERB      ccomp       said
# 22         to         to   PART        aux  stabilize
# 23  stabilize  stabilize   VERB      xcomp        set
# 24          .          .  PUNCT      punct        hit
#
# Dependency Tree opening in browser...
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8c511ba081224537abb97dded7a59bb9-0" class="displacy" width="2690" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">dollar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">hit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">highest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">level</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">against</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">euro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">after</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Federal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">Reserve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">head</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">US</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">trade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">deficit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">set</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">stabilize.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c511ba081224537abb97dded7a59bb9-0-0" stroke-width="2px" d="M70,222.0 C70,167.0 145.0,167.0 145.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c511ba081224537abb97dded7a59bb9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L62,212.0 78,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c511ba081224537abb97dded7a59bb9-0-1" stroke-width="2px" d="M180,222.0 C180,112.0 370.0,112.0 370.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c511ba081224537abb97dded7a59bb9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,224.0 L172,212.0 188,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c511ba081224537abb97dded7a59bb9-0-2" stroke-width="2px" d="M290,222.0 C290,167.0 365.0,167.0 365.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c511ba081224537abb97dded7a59bb9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,224.0 L282,212.0 298,212.0" fill="currentColor
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 33
#      30 print(df)
#      32 print("\nDependency Tree opening in browser...\n")
# ---> 33 visualize_tree(doc, f"sample_tree_{i}.html")
#
# Cell In[9], line 12, in visualize_tree(doc, filename)
#       5 html = displacy.render(
#       6     doc,
#       7     style="dep",
#       8     options={"distance": 110}
#       9 )
#      11 with open(filename, "w", encoding="utf-8") as f:
# ---> 12     f.write(html)
#      14 webbrowser.open("file://" + os.path.realpath(filename))
#
# TypeError: write() argument must be str, not None

# %%
# ================================
# PROCESS NEWS DATASET FILE
# ================================
print("\n================ NEWS DATASET ANALYSIS ================\n")

file_path = "./ML471_S7_Datafile_Concept.txt"

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

doc = nlp(text)

# Only show first 5 sentences visually (avoid too many tabs)
for i, sent in enumerate(doc.sents):
    print("\n" + "-" * 90)
    print(f"Sentence {i + 1}:\n", sent.text.strip())

    df = dependency_table(sent)
    print("\nDependency Table:\n")
    print(df)

    if i < 5:
        print("\nDependency Tree opening in browser...\n")
        visualize_tree(sent, f"news_tree_{i}.html")
# Out:
# ================ NEWS DATASET ANALYSIS ================
#
#
# ------------------------------------------------------------------------------------------
# Sentence 1:
#  News Article 1
# Ad sales boost Time Warner profit
#
# Quarterly profits at US media giant TimeWarner jumped 76% to $1.13bn (£600m) for the three months to December, from $639m year-earlier.
#
# Dependency Table:
#
#          Token       Lemma    POS Dependency  Head Word
# 0         News        News  PROPN   compound    Article
# 1      Article     article   NOUN       nmod      sales
# 2            1           1    NUM     nummod    Article
# 3           \n          \n  SPACE        dep          1
# 4           Ad          ad   NOUN   compound      sales
# 5        sales        sale   NOUN      nsubj      boost
# 6        boost       boost   VERB       ROOT      boost
# 7         Time        Time  PROPN   compound     Warner
# 8       Warner      Warner  PROPN   compound    profits
# 9       profit      profit   NOUN   compound  Quarterly
# 10        \n\n        \n\n  SPACE        dep     profit
# 11   Quarterly   Quarterly  PROPN   compound    profits
# 12     profits      profit   NOUN      nsubj     jumped
# 13          at          at    ADP       prep    profits
# 14          US          US  PROPN   compound      giant
# 15       media      medium   NOUN   compound      giant
# 16       giant       giant   NOUN       pobj         at
# 17  TimeWarner  TimeWarner  PROPN      appos      giant
# 18      jumped        jump   VERB      ccomp      boost
# 19          76          76    NUM     nummod          %
# 20           %           %   NOUN   npadvmod     jumped
# 21          to          to    ADP       prep     jumped
# 22           $           $    SYM       nmod     1.13bn
# 23      1.13bn      1.13bn    NUM       pobj         to
# 24           (           (  PUNCT      punct     1.13bn
# 25           £           £    SYM       nmod        600
# 26         600         600    NUM      appos     1.13bn
# 27           m           m    NUM      appos     1.13bn
# 28           )           )  PUNCT      punct     1.13bn
# 29         for         for    ADP       prep     jumped
# 30         the         the    DET        det     months
# 31       three       three    NUM     nummod     months
# 32      months       month   NOUN       pobj        for
# 33          to          to    ADP       prep     jumped
# 34    December    December  PROPN       pobj         to
# 35           ,           ,  PUNCT      punct     jumped
# 36        from        from    ADP       prep     jumped
# 37           $           $    SYM       nmod        639
# 38         639         639    NUM       pobj       from
# 39           m           m    NUM   npadvmod       from
# 40        year        year   NOUN   npadvmod    earlier
# 41           -           -  PUNCT      punct    earlier
# 42     earlier       early    ADV     advmod       from
# 43           .           .  PUNCT      punct     jumped
# 44        \n\n        \n\n  SPACE        dep          .
#
# Dependency Tree opening in browser...
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="74b9a1878109442b88fed78637ff7784-0" class="displacy" width="4340" height="522.0" direction="ltr" style="max-width: none; height: 522.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">News</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">Article</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">Ad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">sales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">boost</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">Time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">Warner</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">profit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">Quarterly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">profits</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">US</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">media</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">giant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">TimeWarner</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">jumped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">76%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">1.13bn (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">£</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">600</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">m)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">three</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="3240">months</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3240">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">ADP</tspan>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 24
#      22 if i < 5:
#      23     print("\nDependency Tree opening in browser...\n")
# ---> 24     visualize_tree(sent, f"news_tree_{i}.html")
#
# Cell In[9], line 12, in visualize_tree(doc, filename)
#       5 html = displacy.render(
#       6     doc,
#       7     style="dep",
#       8     options={"distance": 110}
#       9 )
#      11 with open(filename, "w", encoding="utf-8") as f:
# ---> 12     f.write(html)
#      14 webbrowser.open("file://" + os.path.realpath(filename))
#
# TypeError: write() argument must be str, not None

# %%
# ================================
# SAVE ALL DEPENDENCIES TO CSV
# ================================
all_data = []

for sent in doc.sents:
    for token in sent:
        all_data.append([
            sent.text,
            token.text,
            token.pos_,
            token.dep_,
            token.head.text
        ])

final_df = pd.DataFrame(all_data, columns=[
    "Sentence",
    "Token",
    "POS",
    "Dependency",
    "Head Word"
])

final_df.to_csv("dependency_output.csv", index=False)

print("\n✅ Dependency analysis completed.")
print("📁 Trees saved as HTML files in project folder.")
print("📊 dependency_output.csv created.")
# Out:
# ✅ Dependency analysis completed.
# 📁 Trees saved as HTML files in project folder.
# 📊 dependency_output.csv created.
